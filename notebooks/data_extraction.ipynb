# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import sys
import mne

# %load_ext autoreload
# %autoreload 2

dir = Path().resolve().parent
print(dir)

if dir not in sys.path:
    sys.path.append(str(dir))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# C:\Users\LENOVO\henry\research\final_thesis\eeg-emotion-analysis

# %%
dens_dir = dir / "data" / "DENS"
gameemo_dir = dir / "data" / "GAMEEMO"

dens_subject_dirs = [dir for dir in dens_dir.iterdir() if dir.is_dir()]
gameemo_subject_dirs = [dir for dir in gameemo_dir.iterdir() if dir.is_dir()]

len(dens_subject_dirs), len(gameemo_subject_dirs)
# Out:
# (41, 29)

# %%
# removing .datalad and GAMEPLAYS folder from DENS and GAMEEMO folders respectively
del dens_subject_dirs[0]
del gameemo_subject_dirs[-1]

# %%
# trial data exploration onto subject 003
subject_003_dir = dens_subject_dirs[0] / "eeg" / "sub-mit003_task-Emotion_eeg.set"
subject_003_raw = mne.io.read_raw_eeglab(subject_003_dir)
# Out:
# Reading C:\Users\LENOVO\henry\research\final_thesis\eeg-emotion-analysis\data\DENS\sub-mit003\eeg\sub-mit003_task-Emotion_eeg.fdt
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7516\956598601.py:2: RuntimeWarning: Unknown types found, setting as type EEG:
# pns: ['ECG', 'EMG', 'EMG_2']
#   subject_003_raw = mne.io.read_raw_eeglab(subject_003_dir)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7516\956598601.py:2: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   subject_003_raw = mne.io.read_raw_eeglab(subject_003_dir)

# %%
# Out:
# <DigMontage | 0 extras (headshape), 0 HPIs, 3 fiducials, 132 channels>
